# %%
import pandas as pd
import os

def ingest_files(directory):
    '''
    This function will ingest every file in the specified directory
    into a pandas dataframe. It will return a dictionary containing
    these dataframes, keyed by the file name.
    
    We assume the directory contains files directly downloaded from
    Webfocus, and *only* those files. Thus, we assume the files are .csv
    
    Note that each file will be read *without* formatting
    '''
    
    # If the directory has no trailing slash, add one
    # if directory[-1] != "\\":
    #     directory = directory + "\\"
    
    all_files = os.listdir(directory)
    output = {}
    
    print("Directory " + directory + " has " + str(len(all_files)) + " files:")
    for i in all_files:
        print("    Reading file " + i)
        output[i] = pd.read_csv(directory + i, dtype = str)
    
    df = pd.concat(output.values(), sort=False).reset_index(drop = True)
    return df

# %%
df = ingest_files("/mnt/c/Users/phess/Downloads/archive/scripts/")
# Out:
# Directory /mnt/c/Users/phess/Downloads/archive/scripts/ has 122 files:
#     Reading file s1e01.csv
#     Reading file s1e02.csv
#     Reading file s1e03.csv
#     Reading file s1e04.csv
#     Reading file s1e05.csv
#     Reading file s1e06.csv
#     Reading file s2e01.csv
#     Reading file s2e02.csv
#     Reading file s2e03.csv
#     Reading file s2e04.csv
#     Reading file s2e05.csv
#     Reading file s2e06.csv
#     Reading file s2e07.csv
#     Reading file s2e08.csv
#     Reading file s2e09.csv
#     Reading file s2e10.csv
#     Reading file s2e11.csv
#     Reading file s2e12.csv
#     Reading file s2e13.csv
#     Reading file s2e14.csv
#     Reading file s2e15.csv
#     Reading file s2e16.csv
#     Reading file s2e17.csv
#     Reading file s2e18.csv
#     Reading file s2e19.csv
#     Reading file s2e20.csv
#     Reading file s2e21.csv
#     Reading file s2e22.csv
#     Reading file s2e23.csv
#     Reading file s2e24.csv
#     Reading file s3e01.csv
#     Reading file s3e02.csv
#     Reading file s3e03.csv
#     Reading file s3e04.csv
#     Reading file s3e05.csv
#     Reading file s3e06.csv
#     Reading file s3e07.csv
#     Reading file s3e08.csv
#     Reading file s3e09.csv
#     Reading file s3e10.csv
#     Reading file s3e11.csv
#     Reading file s3e12.csv
#     Reading file s3e13.csv
#     Reading file s3e14.csv
#     Reading file s3e15.csv
#     Reading file s3e16.csv
#     Reading file s4e01.csv
#     Reading file s4e02.csv
#     Reading file s4e03.csv
#     Reading file s4e04.csv
#     Reading file s4e05.csv
#     Reading file s4e06.csv
#     Reading file s4e07.csv
#     Reading file s4e08.csv
#     Reading file s4e09.csv
#     Reading file s4e10.csv
#     Reading file s4e11.csv
#     Reading file s4e12.csv
#     Reading file s4e13.csv
#     Reading file s4e14.csv
#     Reading file s4e15.csv
#     Reading file s4e16.csv
#     Reading file s4e17.csv
#     Reading file s4e18.csv
#     Reading file s4e19.csv
#     Reading file s4e20.csv
#     Reading file s4e21.csv
#     Reading file s4e22.csv
#     Reading file s5e01.csv
#     Reading file s5e02.csv
#     Reading file s5e03.csv
#     Reading file s5e04.csv
#     Reading file s5e05.csv
#     Reading file s5e06.csv
#     Reading file s5e07.csv
#     Reading file s5e08.csv
#     Reading file s5e09.csv
#     Reading file s5e10.csv
#     Reading file s5e11.csv
#     Reading file s5e12.csv
#     Reading file s5e13.csv
#     Reading file s5e14.csv
#     Reading file s5e15.csv
#     Reading file s5e16.csv
#     Reading file s5e17.csv
#     Reading file s5e18.csv
#     Reading file s5e19.csv
#     Reading file s5e20.csv
#     Reading file s5e21.csv
#     Reading file s5e22.csv
#     Reading file s6e01.csv
#     Reading file s6e02.csv
#     Reading file s6e03.csv
#     Reading file s6e04.csv
#     Reading file s6e05.csv
#     Reading file s6e06.csv
#     Reading file s6e07.csv
#     Reading file s6e08.csv
#     Reading file s6e09.csv
#     Reading file s6e10.csv
#     Reading file s6e11.csv
#     Reading file s6e12.csv
#     Reading file s6e13.csv
#     Reading file s6e14.csv
#     Reading file s6e15.csv
#     Reading file s6e16.csv
#     Reading file s6e17.csv
#     Reading file s6e18.csv
#     Reading file s6e19.csv
#     Reading file s6e20.csv
#     Reading file s7e01.csv
#     Reading file s7e02.csv
#     Reading file s7e03.csv
#     Reading file s7e04.csv
#     Reading file s7e05.csv
#     Reading file s7e06.csv
#     Reading file s7e07.csv
#     Reading file s7e08.csv
#     Reading file s7e09.csv
#     Reading file s7e10.csv
#     Reading file s7e11.csv
#     Reading file s7e12.csv

# %%
df.to_csv("~/git/phess-web/pr-lines.csv")
